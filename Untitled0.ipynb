# %% [markdown]
# <a href="https://colab.research.google.com/github/kevin-wang1009/ytp-omg/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Computer Vision

# %%
import cv2 # opencv
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount("/content/drive")
path = "/content/drive/MyDrive/artist3-active.png"
image = cv2.imread(path)
'''
print(type(image))
print(image.shape) # h, w, c
print(image)

plt.imshow(image) # cv2 (B, G, R)
plt.show()
'''

new_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(new_image)
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
